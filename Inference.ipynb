# %%
import numpy as np
import cv2
import torch
from ultralytics import YOLO

# %% [markdown]
# # YoloV8 Inference

# %%
model = YOLO('./trained_models/yolov8_pretrained/weights/best.pt')

# %%
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/jv/NuimDetector/bus.jpg: 640x480 4 human.pedestrian.adults, 1 vehicle.bus.rigid, 13.0ms
# Speed: 1.2ms preprocess, 13.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)

# %%
results[0].show()

# %% [markdown]
# # YoloV5 Inference

# %%
model = torch.hub.load('/home/jv/yolov5', 'custom', path='./trained_models/v5_pretrained/weights/best.pt', source='local')  # local model
# Out:
# YOLOv5 🚀 v7.0-304-g22361691 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12035MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20945877 parameters, 0 gradients, 48.2 GFLOPs
# Adding AutoShape...

# %%
results = model('https://ultralytics.com/images/bus.jpg')

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=810x1080>
